# %%
import matplotlib.pyplot as plt
import pickle
import os
import snap
from itertools import combinations
import numpy as np
from google.cloud import bigquery
import collections
from IPython.lib import backgroundjobs as bg
from tqdm import tqdm_notebook
import heapq

# %%
with open('./data/project_authors_2016_q1.pickle', 'rb') as picklefile:
    project_authors = pickle.load(picklefile)

# %% [markdown]
# #### Construct an undirectional bipartite graph, note project id are negative

# %%
authors = project_authors['author_id'].unique()
projects = project_authors['project_id'].unique()
bipartite = snap.TUNGraph.New()
for author in authors:
    bipartite.AddNode(author)
for project in projects:
    bipartite.AddNode(-project)
for _, row in project_authors.iterrows():
    bipartite.AddEdge(-row['project_id'], row['author_id'])
bipartite.GetNodes(), bipartite.GetEdges()
# Out:
# (598844, 1081257)

# %%
bipartite_max_scc = snap.GetMxScc(bipartite)
bipartite_max_scc.GetNodes(), bipartite_max_scc.GetEdges()
# Out:
# (213039, 795843)

# %%
author_deg = np.array([node.GetDeg() for node in bipartite_max_scc.Nodes() if node.GetId()>=0])
X = np.unique(author_deg)
Y = [float((author_deg == i).sum())/len(author_deg) for i in X]
plt.loglog(X, Y)
plt.title('Max SCC Author Degree Distribution');

# %%
project_deg = np.array([node.GetDeg() for node in bipartite_max_scc.Nodes() if node.GetId()<0])
X = np.unique(project_deg)
Y = [float((project_deg == i).sum())/len(project_deg) for i in X]
plt.loglog(X, Y)
plt.title('Max SCC Project Degree Distribution');

# %% [markdown]
# ### Remove nodes iteratively, starting from project node with degree 1, and then author node with degree 1, then project node with degree 2 ..etc

# %%
def count_author(graph):
    return len([node for node in graph.Nodes() if node.GetId()>=0])

# %%
bipartite_max_scc = snap.GetMxScc(bipartite)
authors = [node for node in bipartite_max_scc.Nodes() if node.GetId()>=0]
bipartite_max_scc.GetNodes(), bipartite_max_scc.GetEdges()
# Out:
# (213039, 795843)

# %%
author_remaining = [len(authors)]
core = 1
while (count_author(bipartite_max_scc)>1):
    # For every core n, try to delete nodes with degree k=1,2,...n and check if the node count changes.
    # Make sure a clean pass (no node count change) for n times before increasing core to n+1
    clean_pass = 0 
    k = 1
    while (clean_pass <= core):
        core_old = count_author(bipartite_max_scc)
        InDegV = snap.TIntPrV()
        snap.GetNodeInDegV(bipartite_max_scc, InDegV)
        for item in InDegV:
            if item.GetVal2() == k:
                bipartite_max_scc.DelNode(item.GetVal1())
        # Update the graph, make sure it refers to the max SCC
        bipartite_max_scc = snap.GetMxScc(bipartite_max_scc)
        core_update = count_author(bipartite_max_scc)
        if core_old != core_update:
            clean_pass = 0
        else:
            clean_pass += 1
        # Alter the degree count
        if k < core:
            k += 1
        elif k == core:
            k = 1
    print "After deleting nodes degree <= %d, %d nodes remains" % (core, core_update)
    author_remaining.append(core_update)
    core += 1
# Out:
# After deleting nodes degree < 1, 58950 nodes remains
# After deleting nodes degree < 2, 39980 nodes remains
# After deleting nodes degree < 3, 30605 nodes remains
# After deleting nodes degree < 4, 24345 nodes remains
# After deleting nodes degree < 5, 20158 nodes remains
# After deleting nodes degree < 6, 16995 nodes remains
# After deleting nodes degree < 7, 14401 nodes remains
# After deleting nodes degree < 8, 12626 nodes remains
# After deleting nodes degree < 9, 11192 nodes remains
# After deleting nodes degree < 10, 10167 nodes remains
# After deleting nodes degree < 11, 8837 nodes remains
# After deleting nodes degree < 12, 8024 nodes remains
# After deleting nodes degree < 13, 7442 nodes remains
# After deleting nodes degree < 14, 6746 nodes remains
# After deleting nodes degree < 15, 6105 nodes remains
# After deleting nodes degree < 16, 5755 nodes remains
# After deleting nodes degree < 17, 5317 nodes remains
# After deleting nodes degree < 18, 4996 nodes remains
# After deleting nodes degree < 19, 4674 nodes remains
# After deleting nodes degree < 20, 4249 nodes remains
# After deleting nodes degree < 21, 3806 nodes remains
# After deleting nodes degree < 22, 3584 nodes remains
# After deleting nodes degree < 23, 3459 nodes remains
# After deleting nodes degree < 24, 3311 nodes remains
# After deleting nodes degree < 25, 3053 nodes remains
# After deleting nodes degree < 26, 2815 nodes remains
# After deleting nodes degree < 27, 2649 nodes remains
# After deleting nodes degree < 28, 2523 nodes remains
# After deleting nodes degree < 29, 2411 nodes remains
# After deleting nodes degree < 30, 2192 nodes remains
# After deleting nodes degree < 31, 2046 nodes remains
# After deleting nodes degree < 32, 1886 nodes remains
# After deleting nodes degree < 33, 1645 nodes remains
# After deleting nodes degree < 34, 1480 nodes remains
# After deleting nodes degree < 35, 1436 nodes remains
# After deleting nodes degree < 36, 1362 nodes remains
# After deleting nodes degree < 37, 1325 nodes remains
# After deleting nodes degree < 38, 1194 nodes remains
# After deleting nodes degree < 39, 1167 nodes remains
# After deleting nodes degree < 40, 1133 nodes remains
# After deleting nodes degree < 41, 1092 nodes remains
# After deleting nodes degree < 42, 1060 nodes remains
# After deleting nodes degree < 43, 1005 nodes remains
# After deleting nodes degree < 44, 875 nodes remains
# After deleting nodes degree < 45, 856 nodes remains
# After deleting nodes degree < 46, 818 nodes remains
# After deleting nodes degree < 47, 787 nodes remains
# After deleting nodes degree < 48, 692 nodes remains
# After deleting nodes degree < 49, 680 nodes remains
# After deleting nodes degree < 50, 659 nodes remains
# After deleting nodes degree < 51, 626 nodes remains
# After deleting nodes degree < 52, 529 nodes remains
# After deleting nodes degree < 53, 515 nodes remains
# After deleting nodes degree < 54, 507 nodes remains
# After deleting nodes degree < 55, 492 nodes remains
# After deleting nodes degree < 56, 483 nodes remains
# After deleting nodes degree < 57, 468 nodes remains
# After deleting nodes degree < 58, 459 nodes remains
# After deleting nodes degree < 59, 440 nodes remains
# After deleting nodes degree < 60, 426 nodes remains
# After deleting nodes degree < 61, 405 nodes remains
# After deleting nodes degree < 62, 298 nodes remains
# After deleting nodes degree < 63, 282 nodes remains
# After deleting nodes degree < 64, 269 nodes remains
# After deleting nodes degree < 65, 261 nodes remains
# After deleting nodes degree < 66, 253 nodes remains
# After deleting nodes degree < 67, 249 nodes remains
# After deleting nodes degree < 68, 239 nodes remains
# After deleting nodes degree < 69, 218 nodes remains
# After deleting nodes degree < 70, 209 nodes remains
# After deleting nodes degree < 71, 203 nodes remains
# After deleting nodes degree < 72, 203 nodes remains
# After deleting nodes degree < 73, 191 nodes remains
# After deleting nodes degree < 74, 187 nodes remains
# After deleting nodes degree < 75, 148 nodes remains
# After deleting nodes degree < 76, 1 nodes remains
# After deleting nodes degree < 77, 1 nodes remains
# After deleting nodes degree < 78, 1 nodes remains
# After deleting nodes degree < 79, 1 nodes remains
# After deleting nodes degree < 80, 1 nodes remains
# After deleting nodes degree < 81, 1 nodes remains
# After deleting nodes degree < 82, 1 nodes remains
# After deleting nodes degree < 83, 1 nodes remains
# After deleting nodes degree < 84, 1 nodes remains
# After deleting nodes degree < 85, 1 nodes remains
# After deleting nodes degree < 86, 1 nodes remains
# After deleting nodes degree < 87, 1 nodes remains
# After deleting nodes degree < 88, 1 nodes remains
# After deleting nodes degree < 89, 1 nodes remains
# After deleting nodes degree < 90, 1 nodes remains
# After deleting nodes degree < 91, 1 nodes remains
# After deleting nodes degree < 92, 1 nodes remains
# After deleting nodes degree < 93, 1 nodes remains
# After deleting nodes degree < 94, 1 nodes remains
# After deleting nodes degree < 95, 1 nodes remains
# After deleting nodes degree < 96, 1 nodes remains
# After deleting nodes degree < 97, 1 nodes remains
# After deleting nodes degree < 98, 1 nodes remains
# After deleting nodes degree < 99, 1 nodes remains
# After deleting nodes degree < 100, 1 nodes remains
# After deleting nodes degree < 101, 1 nodes remains
# After deleting nodes degree < 102, 1 nodes remains
# After deleting nodes degree < 103, 1 nodes remains
# After deleting nodes degree < 104, 1 nodes remains
# After deleting nodes degree < 105, 1 nodes remains
# After deleting nodes degree < 106, 1 nodes remains
# After deleting nodes degree < 107, 1 nodes remains
# After deleting nodes degree < 108, 1 nodes remains
# After deleting nodes degree < 109, 1 nodes remains
# After deleting nodes degree < 110, 1 nodes remains
# After deleting nodes degree < 111, 1 nodes remains
# After deleting nodes degree < 112, 1 nodes remains
# After deleting nodes degree < 113, 1 nodes remains
# After deleting nodes degree < 114, 1 nodes remains
# After deleting nodes degree < 115, 1 nodes remains
# After deleting nodes degree < 116, 1 nodes remains
# After deleting nodes degree < 117, 1 nodes remains
# After deleting nodes degree < 118, 1 nodes remains
# After deleting nodes degree < 119, 1 nodes remains
# After deleting nodes degree < 120, 1 nodes remains
# After deleting nodes degree < 121, 1 nodes remains
# After deleting nodes degree < 122, 1 nodes remains
# After deleting nodes degree < 123, 1 nodes remains
# After deleting nodes degree < 124, 1 nodes remains
# After deleting nodes degree < 125, 1 nodes remains
# After deleting nodes degree < 126, 1 nodes remains
# After deleting nodes degree < 127, 1 nodes remains
# After deleting nodes degree < 128, 1 nodes remains
# After deleting nodes degree < 129, 1 nodes remains
# After deleting nodes degree < 130, 1 nodes remains
# After deleting nodes degree < 131, 1 nodes remains
# After deleting nodes degree < 132, 1 nodes remains
# After deleting nodes degree < 133, 1 nodes remains
# After deleting nodes degree < 134, 1 nodes remains
# After deleting nodes degree < 135, 1 nodes remains
# After deleting nodes degree < 136, 1 nodes remains
# After deleting nodes degree < 137, 1 nodes remains
# After deleting nodes degree < 138, 1 nodes remains
# After deleting nodes degree < 139, 1 nodes remains
# After deleting nodes degree < 140, 1 nodes remains
# After deleting nodes degree < 141, 1 nodes remains
# After deleting nodes degree < 142, 1 nodes remains
# After deleting nodes degree < 143, 1 nodes remains
# After deleting nodes degree < 144, 1 nodes remains
# After deleting nodes degree < 145, 1 nodes remains
# After deleting nodes degree < 146, 1 nodes remains
# After deleting nodes degree < 147, 1 nodes remains
# After deleting nodes degree < 148, 1 nodes remains
# After deleting nodes degree < 149, 1 nodes remains
# After deleting nodes degree < 150, 1 nodes remains
# After deleting nodes degree < 151, 1 nodes remains
# After deleting nodes degree < 152, 1 nodes remains
# After deleting nodes degree < 153, 1 nodes remains
# After deleting nodes degree < 154, 1 nodes remains
# After deleting nodes degree < 155, 1 nodes remains
# After deleting nodes degree < 156, 1 nodes remains
# After deleting nodes degree < 157, 1 nodes remains
# After deleting nodes degree < 158, 1 nodes remains
# After deleting nodes degree < 159, 1 nodes remains
# After deleting nodes degree < 160, 1 nodes remains
# After deleting nodes degree < 161, 1 nodes remains
# After deleting nodes degree < 162, 1 nodes remains
# After deleting nodes degree < 163, 1 nodes remains
# After deleting nodes degree < 164, 1 nodes remains
# After deleting nodes degree < 165, 1 nodes remains
# After deleting nodes degree < 166, 1 nodes remains
# After deleting nodes degree < 167, 1 nodes remains
# After deleting nodes degree < 168, 1 nodes remains
# After deleting nodes degree < 169, 1 nodes remains
# After deleting nodes degree < 170, 1 nodes remains
# After deleting nodes degree < 171, 1 nodes remains
# After deleting nodes degree < 172, 1 nodes remains
# After deleting nodes degree < 173, 1 nodes remains
# After deleting nodes degree < 174, 1 nodes remains
# After deleting nodes degree < 175, 1 nodes remains
# After deleting nodes degree < 176, 1 nodes remains
# After deleting nodes degree < 177, 1 nodes remains
# After deleting nodes degree < 178, 1 nodes remains
# After deleting nodes degree < 179, 1 nodes remains
# After deleting nodes degree < 180, 1 nodes remains
# After deleting nodes degree < 181, 1 nodes remains
# After deleting nodes degree < 182, 1 nodes remains
# After deleting nodes degree < 183, 1 nodes remains
# After deleting nodes degree < 184, 1 nodes remains
# After deleting nodes degree < 185, 1 nodes remains
# After deleting nodes degree < 186, 1 nodes remains
# After deleting nodes degree < 187, 1 nodes remains
# After deleting nodes degree < 188, 1 nodes remains
# After deleting nodes degree < 189, 1 nodes remains
# After deleting nodes degree < 190, 1 nodes remains
# After deleting nodes degree < 191, 1 nodes remains
# After deleting nodes degree < 192, 1 nodes remains
# After deleting nodes degree < 193, 1 nodes remains
# After deleting nodes degree < 194, 1 nodes remains
# After deleting nodes degree < 195, 1 nodes remains
# After deleting nodes degree < 196, 1 nodes remains
# After deleting nodes degree < 197, 1 nodes remains
# After deleting nodes degree < 198, 1 nodes remains
# After deleting nodes degree < 199, 1 nodes remains
# After deleting nodes degree < 200, 1 nodes remains
# After deleting nodes degree < 201, 1 nodes remains
# After deleting nodes degree < 202, 1 nodes remains
# After deleting nodes degree < 203, 1 nodes remains
# After deleting nodes degree < 204, 1 nodes remains
# After deleting nodes degree < 205, 1 nodes remains
# After deleting nodes degree < 206, 1 nodes remains
# After deleting nodes degree < 207, 1 nodes remains
# After deleting nodes degree < 208, 1 nodes remains
# After deleting nodes degree < 209, 1 nodes remains
# After deleting nodes degree < 210, 1 nodes remains
# After deleting nodes degree < 211, 1 nodes remains
# After deleting nodes degree < 212, 1 nodes remains
# After deleting nodes degree < 213, 1 nodes remains
# After deleting nodes degree < 214, 1 nodes remains
# After deleting nodes degree < 215, 1 nodes remains
# After deleting nodes degree < 216, 1 nodes remains
# After deleting nodes degree < 217, 1 nodes remains
# After deleting nodes degree < 218, 1 nodes remains
# After deleting nodes degree < 219, 1 nodes remains
# After deleting nodes degree < 220, 1 nodes remains
# After deleting nodes degree < 221, 1 nodes remains
# After deleting nodes degree < 222, 1 nodes remains
# After deleting nodes degree < 223, 1 nodes remains
# After deleting nodes degree < 224, 1 nodes remains
# After deleting nodes degree < 225, 1 nodes remains
# After deleting nodes degree < 226, 1 nodes remains
# After deleting nodes degree < 227, 1 nodes remains
# After deleting nodes degree < 228, 1 nodes remains
# After deleting nodes degree < 229, 1 nodes remains
# After deleting nodes degree < 230, 1 nodes remains
# After deleting nodes degree < 231, 1 nodes remains
# After deleting nodes degree < 232, 1 nodes remains
# After deleting nodes degree < 233, 1 nodes remains
# After deleting nodes degree < 234, 1 nodes remains
# After deleting nodes degree < 235, 1 nodes remains
# After deleting nodes degree < 236, 1 nodes remains
# After deleting nodes degree < 237, 1 nodes remains
# After deleting nodes degree < 238, 1 nodes remains
# After deleting nodes degree < 239, 1 nodes remains
# After deleting nodes degree < 240, 1 nodes remains
# After deleting nodes degree < 241, 1 nodes remains
# After deleting nodes degree < 242, 1 nodes remains
# After deleting nodes degree < 243, 1 nodes remains
# After deleting nodes degree < 244, 1 nodes remains
# After deleting nodes degree < 245, 1 nodes remains
# After deleting nodes degree < 246, 1 nodes remains
# After deleting nodes degree < 247, 1 nodes remains
# After deleting nodes degree < 248, 1 nodes remains
# After deleting nodes degree < 249, 1 nodes remains
# After deleting nodes degree < 250, 1 nodes remains
# After deleting nodes degree < 251, 1 nodes remains
# After deleting nodes degree < 252, 1 nodes remains
# After deleting nodes degree < 253, 1 nodes remains
# After deleting nodes degree < 254, 1 nodes remains
# After deleting nodes degree < 255, 1 nodes remains
# After deleting nodes degree < 256, 1 nodes remains
# After deleting nodes degree < 257, 1 nodes remains
# After deleting nodes degree < 258, 1 nodes remains
# After deleting nodes degree < 259, 1 nodes remains
# After deleting nodes degree < 260, 1 nodes remains
# After deleting nodes degree < 261, 1 nodes remains
# After deleting nodes degree < 262, 1 nodes remains
# After deleting nodes degree < 263, 1 nodes remains
# After deleting nodes degree < 264, 1 nodes remains
# After deleting nodes degree < 265, 1 nodes remains
# After deleting nodes degree < 266, 1 nodes remains
# After deleting nodes degree < 267, 1 nodes remains
# After deleting nodes degree < 268, 1 nodes remains
# After deleting nodes degree < 269, 1 nodes remains
# After deleting nodes degree < 270, 1 nodes remains
# After deleting nodes degree < 271, 1 nodes remains
# After deleting nodes degree < 272, 1 nodes remains
# After deleting nodes degree < 273, 1 nodes remains
# After deleting nodes degree < 274, 1 nodes remains
# After deleting nodes degree < 275, 1 nodes remains
# After deleting nodes degree < 276, 1 nodes remains
# After deleting nodes degree < 277, 1 nodes remains
# After deleting nodes degree < 278, 1 nodes remains
# After deleting nodes degree < 279, 1 nodes remains
# After deleting nodes degree < 280, 1 nodes remains
# After deleting nodes degree < 281, 1 nodes remains
# After deleting nodes degree < 282, 1 nodes remains
# After deleting nodes degree < 283, 1 nodes remains
# After deleting nodes degree < 284, 1 nodes remains
# After deleting nodes degree < 285, 1 nodes remains
# After deleting nodes degree < 286, 1 nodes remains
# After deleting nodes degree < 287, 1 nodes remains
# After deleting nodes degree < 288, 1 nodes remains
# After deleting nodes degree < 289, 1 nodes remains
# After deleting nodes degree < 290, 1 nodes remains
# After deleting nodes degree < 291, 1 nodes remains
# After deleting nodes degree < 292, 1 nodes remains
# After deleting nodes degree < 293, 1 nodes remains
# After deleting nodes degree < 294, 1 nodes remains
# After deleting nodes degree < 295, 1 nodes remains
# After deleting nodes degree < 296, 1 nodes remains
# After deleting nodes degree < 297, 1 nodes remains
# After deleting nodes degree < 298, 1 nodes remains
# After deleting nodes degree < 299, 1 nodes remains
# After deleting nodes degree < 300, 1 nodes remains
# After deleting nodes degree < 301, 1 nodes remains
# After deleting nodes degree < 302, 1 nodes remains
# After deleting nodes degree < 303, 1 nodes remains
# After deleting nodes degree < 304, 1 nodes remains
# After deleting nodes degree < 305, 1 nodes remains
# After deleting nodes degree < 306, 1 nodes remains
# After deleting nodes degree < 307, 1 nodes remains
# After deleting nodes degree < 308, 1 nodes remains
# After deleting nodes degree < 309, 1 nodes remains
# After deleting nodes degree < 310, 1 nodes remains
# After deleting nodes degree < 311, 1 nodes remains
# After deleting nodes degree < 312, 1 nodes remains
# After deleting nodes degree < 313, 1 nodes remains
# After deleting nodes degree < 314, 1 nodes remains
# After deleting nodes degree < 315, 1 nodes remains
# After deleting nodes degree < 316, 1 nodes remains
# After deleting nodes degree < 317, 1 nodes remains
# After deleting nodes degree < 318, 1 nodes remains
# After deleting nodes degree < 319, 1 nodes remains
# After deleting nodes degree < 320, 1 nodes remains
# After deleting nodes degree < 321, 1 nodes remains
# After deleting nodes degree < 322, 1 nodes remains
# After deleting nodes degree < 323, 1 nodes remains
# After deleting nodes degree < 324, 1 nodes remains
# After deleting nodes degree < 325, 1 nodes remains
# After deleting nodes degree < 326, 1 nodes remains
# After deleting nodes degree < 327, 1 nodes remains
# After deleting nodes degree < 328, 1 nodes remains
# After deleting nodes degree < 329, 1 nodes remains
# After deleting nodes degree < 330, 1 nodes remains
# After deleting nodes degree < 331, 1 nodes remains
# After deleting nodes degree < 332, 1 nodes remains
# After deleting nodes degree < 333, 1 nodes remains
# After deleting nodes degree < 334, 1 nodes remains
# After deleting nodes degree < 335, 1 nodes remains
# After deleting nodes degree < 336, 1 nodes remains
# After deleting nodes degree < 337, 1 nodes remains
# After deleting nodes degree < 338, 1 nodes remains
# After deleting nodes degree < 339, 1 nodes remains
# After deleting nodes degree < 340, 1 nodes remains
# After deleting nodes degree < 341, 1 nodes remains
# After deleting nodes degree < 342, 1 nodes remains
# After deleting nodes degree < 343, 1 nodes remains
# After deleting nodes degree < 344, 1 nodes remains
# After deleting nodes degree < 345, 1 nodes remains
# After deleting nodes degree < 346, 1 nodes remains
# After deleting nodes degree < 347, 1 nodes remains
# After deleting nodes degree < 348, 1 nodes remains
# After deleting nodes degree < 349, 1 nodes remains
# After deleting nodes degree < 350, 1 nodes remains
# After deleting nodes degree < 351, 1 nodes remains
# After deleting nodes degree < 352, 1 nodes remains
# After deleting nodes degree < 353, 1 nodes remains
# After deleting nodes degree < 354, 1 nodes remains
# After deleting nodes degree < 355, 1 nodes remains
# After deleting nodes degree < 356, 1 nodes remains
# After deleting nodes degree < 357, 1 nodes remains
# After deleting nodes degree < 358, 1 nodes remains
# After deleting nodes degree < 359, 1 nodes remains
# After deleting nodes degree < 360, 1 nodes remains
# After deleting nodes degree < 361, 1 nodes remains
# After deleting nodes degree < 362, 1 nodes remains
# After deleting nodes degree < 363, 1 nodes remains
# After deleting nodes degree < 364, 1 nodes remains
# After deleting nodes degree < 365, 1 nodes remains
# After deleting nodes degree < 366, 1 nodes remains
# After deleting nodes degree < 367, 1 nodes remains
# After deleting nodes degree < 368, 1 nodes remains
# After deleting nodes degree < 369, 1 nodes remains
# After deleting nodes degree < 370, 1 nodes remains
# After deleting nodes degree < 371, 1 nodes remains
# After deleting nodes degree < 372, 1 nodes remains
# After deleting nodes degree < 373, 1 nodes remains
# After deleting nodes degree < 374, 1 nodes remains
# After deleting nodes degree < 375, 1 nodes remains
# After deleting nodes degree < 376, 1 nodes remains
# After deleting nodes degree < 377, 1 nodes remains
# After deleting nodes degree < 378, 1 nodes remains
# After deleting nodes degree < 379, 1 nodes remains
# After deleting nodes degree < 380, 1 nodes remains
# After deleting nodes degree < 381, 1 nodes remains
# After deleting nodes degree < 382, 1 nodes remains
# After deleting nodes degree < 383, 1 nodes remains
# After deleting nodes degree < 384, 1 nodes remains
# After deleting nodes degree < 385, 1 nodes remains
# After deleting nodes degree < 386, 1 nodes remains
# After deleting nodes degree < 387, 1 nodes remains
# After deleting nodes degree < 388, 1 nodes remains
# After deleting nodes degree < 389, 1 nodes remains
# After deleting nodes degree < 390, 1 nodes remains
# After deleting nodes degree < 391, 1 nodes remains
# After deleting nodes degree < 392, 1 nodes remains
# After deleting nodes degree < 393, 1 nodes remains
# After deleting nodes degree < 394, 1 nodes remains
# After deleting nodes degree < 395, 1 nodes remains
# After deleting nodes degree < 396, 1 nodes remains
# After deleting nodes degree < 397, 1 nodes remains
# After deleting nodes degree < 398, 1 nodes remains
# After deleting nodes degree < 399, 1 nodes remains
# After deleting nodes degree < 400, 1 nodes remains
# After deleting nodes degree < 401, 1 nodes remains
# After deleting nodes degree < 402, 1 nodes remains
# After deleting nodes degree < 403, 1 nodes remains
# After deleting nodes degree < 404, 1 nodes remains
# After deleting nodes degree < 405, 1 nodes remains
# After deleting nodes degree < 406, 1 nodes remains
# After deleting nodes degree < 407, 1 nodes remains
# After deleting nodes degree < 408, 1 nodes remains
# After deleting nodes degree < 409, 1 nodes remains
# After deleting nodes degree < 410, 1 nodes remains
# After deleting nodes degree < 411, 1 nodes remains
# After deleting nodes degree < 412, 1 nodes remains
# After deleting nodes degree < 413, 1 nodes remains
# After deleting nodes degree < 414, 1 nodes remains
# After deleting nodes degree < 415, 1 nodes remains
# After deleting nodes degree < 416, 1 nodes remains
# After deleting nodes degree < 417, 1 nodes remains
# After deleting nodes degree < 418, 1 nodes remains
# After deleting nodes degree < 419, 1 nodes remains
# After deleting nodes degree < 420, 1 nodes remains
# After deleting nodes degree < 421, 1 nodes remains
# After deleting nodes degree < 422, 1 nodes remains
# After deleting nodes degree < 423, 1 nodes remains
# After deleting nodes degree < 424, 1 nodes remains
# After deleting nodes degree < 425, 1 nodes remains
# After deleting nodes degree < 426, 1 nodes remains
# After deleting nodes degree < 427, 1 nodes remains
# After deleting nodes degree < 428, 1 nodes remains
# After deleting nodes degree < 429, 1 nodes remains
# After deleting nodes degree < 430, 1 nodes remains
# After deleting nodes degree < 431, 1 nodes remains
# After deleting nodes degree < 432, 1 nodes remains
# After deleting nodes degree < 433, 1 nodes remains
# After deleting nodes degree < 434, 1 nodes remains
# After deleting nodes degree < 435, 1 nodes remains
# After deleting nodes degree < 436, 1 nodes remains
# After deleting nodes degree < 437, 1 nodes remains
# After deleting nodes degree < 438, 1 nodes remains
# After deleting nodes degree < 439, 1 nodes remains
# After deleting nodes degree < 440, 1 nodes remains
# After deleting nodes degree < 441, 1 nodes remains
# After deleting nodes degree < 442, 1 nodes remains
# After deleting nodes degree < 443, 1 nodes remains
# After deleting nodes degree < 444, 1 nodes remains
# After deleting nodes degree < 445, 1 nodes remains
# After deleting nodes degree < 446, 1 nodes remains
# After deleting nodes degree < 447, 1 nodes remains
# After deleting nodes degree < 448, 1 nodes remains
# After deleting nodes degree < 449, 1 nodes remains
# After deleting nodes degree < 450, 1 nodes remains
# After deleting nodes degree < 451, 1 nodes remains
# After deleting nodes degree < 452, 1 nodes remains
# After deleting nodes degree < 453, 1 nodes remains
# After deleting nodes degree < 454, 1 nodes remains
# After deleting nodes degree < 455, 1 nodes remains
# After deleting nodes degree < 456, 1 nodes remains
# After deleting nodes degree < 457, 1 nodes remains
# After deleting nodes degree < 458, 1 nodes remains
# After deleting nodes degree < 459, 1 nodes remains
# After deleting nodes degree < 460, 1 nodes remains
# After deleting nodes degree < 461, 1 nodes remains
# After deleting nodes degree < 462, 1 nodes remains
# After deleting nodes degree < 463, 1 nodes remains
# After deleting nodes degree < 464, 1 nodes remains
# After deleting nodes degree < 465, 1 nodes remains
# After deleting nodes degree < 466, 1 nodes remains
# After deleting nodes degree < 467, 1 nodes remains
# After deleting nodes degree < 468, 1 nodes remains
# After deleting nodes degree < 469, 1 nodes remains
# After deleting nodes degree < 470, 1 nodes remains
# After deleting nodes degree < 471, 1 nodes remains
# After deleting nodes degree < 472, 1 nodes remains
# After deleting nodes degree < 473, 1 nodes remains
# After deleting nodes degree < 474, 1 nodes remains
# After deleting nodes degree < 475, 1 nodes remains
# After deleting nodes degree < 476, 1 nodes remains
# After deleting nodes degree < 477, 1 nodes remains
# After deleting nodes degree < 478, 1 nodes remains
# After deleting nodes degree < 479, 1 nodes remains
# After deleting nodes degree < 480, 1 nodes remains
# After deleting nodes degree < 481, 1 nodes remains
# After deleting nodes degree < 482, 1 nodes remains
# After deleting nodes degree < 483, 1 nodes remains
# After deleting nodes degree < 484, 1 nodes remains
# After deleting nodes degree < 485, 1 nodes remains
# After deleting nodes degree < 486, 1 nodes remains
# After deleting nodes degree < 487, 1 nodes remains
# After deleting nodes degree < 488, 1 nodes remains
# After deleting nodes degree < 489, 1 nodes remains
# After deleting nodes degree < 490, 1 nodes remains
# After deleting nodes degree < 491, 1 nodes remains
# After deleting nodes degree < 492, 1 nodes remains
# After deleting nodes degree < 493, 1 nodes remains
# After deleting nodes degree < 494, 1 nodes remains
# After deleting nodes degree < 495, 1 nodes remains
# After deleting nodes degree < 496, 1 nodes remains
# After deleting nodes degree < 497, 1 nodes remains
# After deleting nodes degree < 498, 1 nodes remains
# After deleting nodes degree < 499, 1 nodes remains
# After deleting nodes degree < 500, 1 nodes remains
# After deleting nodes degree < 501, 1 nodes remains
# After deleting nodes degree < 502, 1 nodes remains
# After deleting nodes degree < 503, 1 nodes remains
# After deleting nodes degree < 504, 1 nodes remains
# After deleting nodes degree < 505, 1 nodes remains
# After deleting nodes degree < 506, 1 nodes remains
# After deleting nodes degree < 507, 1 nodes remains
# After deleting nodes degree < 508, 1 nodes remains
# After deleting nodes degree < 509, 1 nodes remains
# After deleting nodes degree < 510, 1 nodes remains
# After deleting nodes degree < 511, 1 nodes remains
# After deleting nodes degree < 512, 1 nodes remains
# After deleting nodes degree < 513, 1 nodes remains
# After deleting nodes degree < 514, 1 nodes remains
# After deleting nodes degree < 515, 1 nodes remains
# After deleting nodes degree < 516, 1 nodes remains
# After deleting nodes degree < 517, 1 nodes remains
# After deleting nodes degree < 518, 1 nodes remains
# After deleting nodes degree < 519, 1 nodes remains
# After deleting nodes degree < 520, 1 nodes remains
# After deleting nodes degree < 521, 1 nodes remains
# After deleting nodes degree < 522, 1 nodes remains
# After deleting nodes degree < 523, 1 nodes remains
# After deleting nodes degree < 524, 1 nodes remains
# After deleting nodes degree < 525, 1 nodes remains
# After deleting nodes degree < 526, 1 nodes remains
# After deleting nodes degree < 527, 1 nodes remains
# After deleting nodes degree < 528, 1 nodes remains
# After deleting nodes degree < 529, 1 nodes remains
# After deleting nodes degree < 530, 1 nodes remains
# After deleting nodes degree < 531, 1 nodes remains
# After deleting nodes degree < 532, 1 nodes remains
# After deleting nodes degree < 533, 1 nodes remains
# After deleting nodes degree < 534, 1 nodes remains
# After deleting nodes degree < 535, 1 nodes remains
# After deleting nodes degree < 536, 1 nodes remains
# After deleting nodes degree < 537, 1 nodes remains
# After deleting nodes degree < 538, 1 nodes remains
# After deleting nodes degree < 539, 1 nodes remains
# After deleting nodes degree < 540, 1 nodes remains
# After deleting nodes degree < 541, 1 nodes remains
# After deleting nodes degree < 542, 1 nodes remains
# After deleting nodes degree < 543, 1 nodes remains
# After deleting nodes degree < 544, 1 nodes remains
# After deleting nodes degree < 545, 1 nodes remains
# After deleting nodes degree < 546, 1 nodes remains
# After deleting nodes degree < 547, 1 nodes remains
# After deleting nodes degree < 548, 1 nodes remains
# After deleting nodes degree < 549, 1 nodes remains
# After deleting nodes degree < 550, 1 nodes remains
# After deleting nodes degree < 551, 1 nodes remains
# After deleting nodes degree < 552, 1 nodes remains
# After deleting nodes degree < 553, 1 nodes remains
# After deleting nodes degree < 554, 1 nodes remains
# After deleting nodes degree < 555, 1 nodes remains
# After deleting nodes degree < 556, 1 nodes remains
# After deleting nodes degree < 557, 1 nodes remains
# After deleting nodes degree < 558, 1 nodes remains
# After deleting nodes degree < 559, 1 nodes remains
# After deleting nodes degree < 560, 1 nodes remains
# After deleting nodes degree < 561, 1 nodes remains
# After deleting nodes degree < 562, 1 nodes remains
# After deleting nodes degree < 563, 1 nodes remains
# After deleting nodes degree < 564, 1 nodes remains
# After deleting nodes degree < 565, 1 nodes remains
# After deleting nodes degree < 566, 1 nodes remains
# After deleting nodes degree < 567, 1 nodes remains
# After deleting nodes degree < 568, 1 nodes remains
# After deleting nodes degree < 569, 1 nodes remains
# After deleting nodes degree < 570, 1 nodes remains
# After deleting nodes degree < 571, 1 nodes remains
# After deleting nodes degree < 572, 1 nodes remains
# After deleting nodes degree < 573, 1 nodes remains
# After deleting nodes degree < 574, 1 nodes remains
# After deleting nodes degree < 575, 1 nodes remains
# After deleting nodes degree < 576, 1 nodes remains
# After deleting nodes degree < 577, 1 nodes remains
# After deleting nodes degree < 578, 1 nodes remains
# After deleting nodes degree < 579, 1 nodes remains
# After deleting nodes degree < 580, 1 nodes remains
# After deleting nodes degree < 581, 1 nodes remains
# After deleting nodes degree < 582, 1 nodes remains
# After deleting nodes degree < 583, 1 nodes remains
# After deleting nodes degree < 584, 1 nodes remains
# After deleting nodes degree < 585, 1 nodes remains
# After deleting nodes degree < 586, 1 nodes remains
# After deleting nodes degree < 587, 1 nodes remains
# After deleting nodes degree < 588, 1 nodes remains
# After deleting nodes degree < 589, 1 nodes remains
# After deleting nodes degree < 590, 1 nodes remains
# After deleting nodes degree < 591, 1 nodes remains
# After deleting nodes degree < 592, 1 nodes remains
# After deleting nodes degree < 593, 1 nodes remains
# After deleting nodes degree < 594, 1 nodes remains
# After deleting nodes degree < 595, 1 nodes remains
# After deleting nodes degree < 596, 1 nodes remains
# After deleting nodes degree < 597, 1 nodes remains
# After deleting nodes degree < 598, 1 nodes remains
# After deleting nodes degree < 599, 1 nodes remains
# After deleting nodes degree < 600, 1 nodes remains
# After deleting nodes degree < 601, 1 nodes remains
# After deleting nodes degree < 602, 1 nodes remains
# After deleting nodes degree < 603, 1 nodes remains
# After deleting nodes degree < 604, 1 nodes remains
# After deleting nodes degree < 605, 1 nodes remains
# After deleting nodes degree < 606, 1 nodes remains
# After deleting nodes degree < 607, 1 nodes remains
# After deleting nodes degree < 608, 1 nodes remains
# After deleting nodes degree < 609, 1 nodes remains
# After deleting nodes degree < 610, 1 nodes remains
# After deleting nodes degree < 611, 1 nodes remains
# After deleting nodes degree < 612, 1 nodes remains
# After deleting nodes degree < 613, 1 nodes remains
# After deleting nodes degree < 614, 1 nodes remains
# After deleting nodes degree < 615, 1 nodes remains
# After deleting nodes degree < 616, 1 nodes remains
# After deleting nodes degree < 617, 1 nodes remains
# After deleting nodes degree < 618, 1 nodes remains
# After deleting nodes degree < 619, 1 nodes remains
# After deleting nodes degree < 620, 1 nodes remains
# After deleting nodes degree < 621, 1 nodes remains
# After deleting nodes degree < 622, 1 nodes remains
# After deleting nodes degree < 623, 1 nodes remains
# After deleting nodes degree < 624, 1 nodes remains
# After deleting nodes degree < 625, 1 nodes remains
# After deleting nodes degree < 626, 1 nodes remains
# After deleting nodes degree < 627, 1 nodes remains
# After deleting nodes degree < 628, 1 nodes remains
# After deleting nodes degree < 629, 1 nodes remains
# After deleting nodes degree < 630, 1 nodes remains
# After deleting nodes degree < 631, 1 nodes remains
# After deleting nodes degree < 632, 1 nodes remains
# After deleting nodes degree < 633, 1 nodes remains
# After deleting nodes degree < 634, 1 nodes remains
# After deleting nodes degree < 635, 1 nodes remains
# After deleting nodes degree < 636, 1 nodes remains
# After deleting nodes degree < 637, 1 nodes remains
# After deleting nodes degree < 638, 1 nodes remains
# After deleting nodes degree < 639, 1 nodes remains
# After deleting nodes degree < 640, 1 nodes remains
# After deleting nodes degree < 641, 1 nodes remains
# After deleting nodes degree < 642, 1 nodes remains
# After deleting nodes degree < 643, 1 nodes remains
# After deleting nodes degree < 644, 1 nodes remains
# After deleting nodes degree < 645, 1 nodes remains
# After deleting nodes degree < 646, 1 nodes remains
# After deleting nodes degree < 647, 1 nodes remains
# After deleting nodes degree < 648, 1 nodes remains
# After deleting nodes degree < 649, 1 nodes remains
# After deleting nodes degree < 650, 1 nodes remains
# After deleting nodes degree < 651, 1 nodes remains
# After deleting nodes degree < 652, 1 nodes remains
# After deleting nodes degree < 653, 1 nodes remains
# After deleting nodes degree < 654, 1 nodes remains
# After deleting nodes degree < 655, 1 nodes remains
# After deleting nodes degree < 656, 1 nodes remains
# After deleting nodes degree < 657, 1 nodes remains
# After deleting nodes degree < 658, 1 nodes remains
# After deleting nodes degree < 659, 1 nodes remains
# After deleting nodes degree < 660, 1 nodes remains
# After deleting nodes degree < 661, 1 nodes remains
# After deleting nodes degree < 662, 1 nodes remains
# After deleting nodes degree < 663, 1 nodes remains
# After deleting nodes degree < 664, 1 nodes remains
# After deleting nodes degree < 665, 1 nodes remains
# After deleting nodes degree < 666, 1 nodes remains
# After deleting nodes degree < 667, 1 nodes remains
# After deleting nodes degree < 668, 1 nodes remains
# After deleting nodes degree < 669, 1 nodes remains
# After deleting nodes degree < 670, 1 nodes remains
# After deleting nodes degree < 671, 1 nodes remains
# After deleting nodes degree < 672, 1 nodes remains
# After deleting nodes degree < 673, 1 nodes remains
# After deleting nodes degree < 674, 1 nodes remains
# After deleting nodes degree < 675, 1 nodes remains
# After deleting nodes degree < 676, 1 nodes remains
# After deleting nodes degree < 677, 1 nodes remains
# After deleting nodes degree < 678, 1 nodes remains
# After deleting nodes degree < 679, 1 nodes remains
# After deleting nodes degree < 680, 1 nodes remains
# After deleting nodes degree < 681, 1 nodes remains
# After deleting nodes degree < 682, 1 nodes remains
# After deleting nodes degree < 683, 1 nodes remains
# After deleting nodes degree < 684, 1 nodes remains
# After deleting nodes degree < 685, 1 nodes remains
# After deleting nodes degree < 686, 1 nodes remains
# After deleting nodes degree < 687, 1 nodes remains
# After deleting nodes degree < 688, 1 nodes remains
# After deleting nodes degree < 689, 1 nodes remains
# After deleting nodes degree < 690, 1 nodes remains
# After deleting nodes degree < 691, 1 nodes remains
# After deleting nodes degree < 692, 1 nodes remains
# After deleting nodes degree < 693, 1 nodes remains
# After deleting nodes degree < 694, 1 nodes remains
# After deleting nodes degree < 695, 1 nodes remains
# After deleting nodes degree < 696, 1 nodes remains
# After deleting nodes degree < 697, 1 nodes remains
# After deleting nodes degree < 698, 1 nodes remains
# After deleting nodes degree < 699, 1 nodes remains
# After deleting nodes degree < 700, 1 nodes remains
# After deleting nodes degree < 701, 1 nodes remains
# After deleting nodes degree < 702, 1 nodes remains
# After deleting nodes degree < 703, 1 nodes remains
# After deleting nodes degree < 704, 1 nodes remains
# After deleting nodes degree < 705, 1 nodes remains
# After deleting nodes degree < 706, 1 nodes remains
# After deleting nodes degree < 707, 1 nodes remains
# After deleting nodes degree < 708, 1 nodes remains
# After deleting nodes degree < 709, 1 nodes remains
# After deleting nodes degree < 710, 1 nodes remains
# After deleting nodes degree < 711, 1 nodes remains
# After deleting nodes degree < 712, 1 nodes remains
# After deleting nodes degree < 713, 1 nodes remains
# After deleting nodes degree < 714, 1 nodes remains
# After deleting nodes degree < 715, 1 nodes remains
# After deleting nodes degree < 716, 1 nodes remains
# After deleting nodes degree < 717, 1 nodes remains
# After deleting nodes degree < 718, 1 nodes remains
# After deleting nodes degree < 719, 1 nodes remains
# After deleting nodes degree < 720, 1 nodes remains
# After deleting nodes degree < 721, 1 nodes remains
# After deleting nodes degree < 722, 1 nodes remains
# After deleting nodes degree < 723, 1 nodes remains
# After deleting nodes degree < 724, 1 nodes remains
# After deleting nodes degree < 725, 1 nodes remains
# After deleting nodes degree < 726, 1 nodes remains
# After deleting nodes degree < 727, 1 nodes remains
# After deleting nodes degree < 728, 1 nodes remains
# After deleting nodes degree < 729, 1 nodes remains
# After deleting nodes degree < 730, 1 nodes remains
# After deleting nodes degree < 731, 1 nodes remains
# After deleting nodes degree < 732, 1 nodes remains
# After deleting nodes degree < 733, 1 nodes remains
# After deleting nodes degree < 734, 1 nodes remains
# After deleting nodes degree < 735, 1 nodes remains
# After deleting nodes degree < 736, 1 nodes remains
# After deleting nodes degree < 737, 1 nodes remains
# After deleting nodes degree < 738, 1 nodes remains
# After deleting nodes degree < 739, 1 nodes remains
# After deleting nodes degree < 740, 1 nodes remains
# After deleting nodes degree < 741, 1 nodes remains
# After deleting nodes degree < 742, 1 nodes remains
# After deleting nodes degree < 743, 1 nodes remains
# After deleting nodes degree < 744, 1 nodes remains
# After deleting nodes degree < 745, 1 nodes remains
# After deleting nodes degree < 746, 1 nodes remains
# After deleting nodes degree < 747, 1 nodes remains
# After deleting nodes degree < 748, 1 nodes remains
# After deleting nodes degree < 749, 1 nodes remains
# After deleting nodes degree < 750, 1 nodes remains
# After deleting nodes degree < 751, 1 nodes remains
# After deleting nodes degree < 752, 1 nodes remains
# After deleting nodes degree < 753, 1 nodes remains
# After deleting nodes degree < 754, 1 nodes remains
# After deleting nodes degree < 755, 1 nodes remains
# After deleting nodes degree < 756, 1 nodes remains
# After deleting nodes degree < 757, 1 nodes remains
# After deleting nodes degree < 758, 1 nodes remains
# After deleting nodes degree < 759, 1 nodes remains
# After deleting nodes degree < 760, 1 nodes remains
# After deleting nodes degree < 761, 1 nodes remains
# After deleting nodes degree < 762, 1 nodes remains
# After deleting nodes degree < 763, 1 nodes remains
# After deleting nodes degree < 764, 1 nodes remains
# After deleting nodes degree < 765, 1 nodes remains
# After deleting nodes degree < 766, 1 nodes remains
# After deleting nodes degree < 767, 1 nodes remains
# After deleting nodes degree < 768, 1 nodes remains
# After deleting nodes degree < 769, 1 nodes remains
# After deleting nodes degree < 770, 1 nodes remains
# After deleting nodes degree < 771, 1 nodes remains
# After deleting nodes degree < 772, 1 nodes remains
# After deleting nodes degree < 773, 1 nodes remains
# After deleting nodes degree < 774, 1 nodes remains
# After deleting nodes degree < 775, 1 nodes remains
# After deleting nodes degree < 776, 1 nodes remains
# After deleting nodes degree < 777, 1 nodes remains
# After deleting nodes degree < 778, 1 nodes remains
# After deleting nodes degree < 779, 1 nodes remains
# After deleting nodes degree < 780, 1 nodes remains
# After deleting nodes degree < 781, 1 nodes remains
# After deleting nodes degree < 782, 1 nodes remains
# After deleting nodes degree < 783, 1 nodes remains
# After deleting nodes degree < 784, 1 nodes remains
# After deleting nodes degree < 785, 1 nodes remains
# After deleting nodes degree < 786, 1 nodes remains
# After deleting nodes degree < 787, 1 nodes remains
# After deleting nodes degree < 788, 1 nodes remains
# After deleting nodes degree < 789, 1 nodes remains
# After deleting nodes degree < 790, 1 nodes remains
# After deleting nodes degree < 791, 1 nodes remains
# After deleting nodes degree < 792, 1 nodes remains
# After deleting nodes degree < 793, 1 nodes remains
# After deleting nodes degree < 794, 1 nodes remains
# After deleting nodes degree < 795, 1 nodes remains
# After deleting nodes degree < 796, 1 nodes remains
# After deleting nodes degree < 797, 1 nodes remains
# After deleting nodes degree < 798, 1 nodes remains
# After deleting nodes degree < 799, 1 nodes remains
# After deleting nodes degree < 800, 1 nodes remains
# After deleting nodes degree < 801, 1 nodes remains
# After deleting nodes degree < 802, 1 nodes remains
# After deleting nodes degree < 803, 1 nodes remains
# After deleting nodes degree < 804, 1 nodes remains
# After deleting nodes degree < 805, 1 nodes remains
# After deleting nodes degree < 806, 1 nodes remains
# After deleting nodes degree < 807, 1 nodes remains
# After deleting nodes degree < 808, 1 nodes remains
# After deleting nodes degree < 809, 1 nodes remains
# After deleting nodes degree < 810, 1 nodes remains
# After deleting nodes degree < 811, 1 nodes remains
# After deleting nodes degree < 812, 1 nodes remains
# After deleting nodes degree < 813, 1 nodes remains
# After deleting nodes degree < 814, 1 nodes remains
# After deleting nodes degree < 815, 1 nodes remains
# After deleting nodes degree < 816, 1 nodes remains
# After deleting nodes degree < 817, 1 nodes remains
# After deleting nodes degree < 818, 1 nodes remains
# After deleting nodes degree < 819, 1 nodes remains
# After deleting nodes degree < 820, 1 nodes remains
# After deleting nodes degree < 821, 1 nodes remains
# After deleting nodes degree < 822, 1 nodes remains
# After deleting nodes degree < 823, 1 nodes remains
# After deleting nodes degree < 824, 1 nodes remains
# After deleting nodes degree < 825, 1 nodes remains
# After deleting nodes degree < 826, 1 nodes remains
# After deleting nodes degree < 827, 1 nodes remains
# After deleting nodes degree < 828, 1 nodes remains
# After deleting nodes degree < 829, 1 nodes remains
# After deleting nodes degree < 830, 1 nodes remains
# After deleting nodes degree < 831, 1 nodes remains
# After deleting nodes degree < 832, 1 nodes remains
# After deleting nodes degree < 833, 1 nodes remains
# After deleting nodes degree < 834, 1 nodes remains
# After deleting nodes degree < 835, 1 nodes remains
# After deleting nodes degree < 836, 1 nodes remains
# After deleting nodes degree < 837, 1 nodes remains
# After deleting nodes degree < 838, 1 nodes remains
# After deleting nodes degree < 839, 1 nodes remains
# After deleting nodes degree < 840, 1 nodes remains
# After deleting nodes degree < 841, 1 nodes remains
# After deleting nodes degree < 842, 1 nodes remains
# After deleting nodes degree < 843, 1 nodes remains
# After deleting nodes degree < 844, 1 nodes remains
# After deleting nodes degree < 845, 1 nodes remains
# After deleting nodes degree < 846, 1 nodes remains
# After deleting nodes degree < 847, 1 nodes remains
# After deleting nodes degree < 848, 1 nodes remains
# After deleting nodes degree < 849, 1 nodes remains
# After deleting nodes degree < 850, 1 nodes remains
# After deleting nodes degree < 851, 1 nodes remains
# After deleting nodes degree < 852, 1 nodes remains
# After deleting nodes degree < 853, 1 nodes remains
# After deleting nodes degree < 854, 1 nodes remains
# After deleting nodes degree < 855, 1 nodes remains
# After deleting nodes degree < 856, 1 nodes remains
# After deleting nodes degree < 857, 1 nodes remains
# After deleting nodes degree < 858, 1 nodes remains
# After deleting nodes degree < 859, 1 nodes remains
# After deleting nodes degree < 860, 1 nodes remains
# After deleting nodes degree < 861, 1 nodes remains
# After deleting nodes degree < 862, 1 nodes remains
# After deleting nodes degree < 863, 1 nodes remains
# After deleting nodes degree < 864, 1 nodes remains
# After deleting nodes degree < 865, 1 nodes remains
# After deleting nodes degree < 866, 1 nodes remains
# After deleting nodes degree < 867, 1 nodes remains
# After deleting nodes degree < 868, 1 nodes remains
# After deleting nodes degree < 869, 1 nodes remains
# After deleting nodes degree < 870, 1 nodes remains
# After deleting nodes degree < 871, 1 nodes remains
# After deleting nodes degree < 872, 1 nodes remains
# After deleting nodes degree < 873, 1 nodes remains
# After deleting nodes degree < 874, 1 nodes remains
# After deleting nodes degree < 875, 1 nodes remains
# After deleting nodes degree < 876, 1 nodes remains
# After deleting nodes degree < 877, 1 nodes remains
# After deleting nodes degree < 878, 1 nodes remains
# After deleting nodes degree < 879, 1 nodes remains
# After deleting nodes degree < 880, 1 nodes remains
# After deleting nodes degree < 881, 1 nodes remains
# After deleting nodes degree < 882, 1 nodes remains
# After deleting nodes degree < 883, 1 nodes remains
# After deleting nodes degree < 884, 1 nodes remains
# After deleting nodes degree < 885, 1 nodes remains
# After deleting nodes degree < 886, 1 nodes remains
# After deleting nodes degree < 887, 1 nodes remains
# After deleting nodes degree < 888, 1 nodes remains
# After deleting nodes degree < 889, 1 nodes remains
# After deleting nodes degree < 890, 1 nodes remains
# After deleting nodes degree < 891, 1 nodes remains
# After deleting nodes degree < 892, 1 nodes remains
# After deleting nodes degree < 893, 1 nodes remains
# After deleting nodes degree < 894, 1 nodes remains
# After deleting nodes degree < 895, 1 nodes remains
# After deleting nodes degree < 896, 1 nodes remains
# After deleting nodes degree < 897, 1 nodes remains
# After deleting nodes degree < 898, 1 nodes remains
# After deleting nodes degree < 899, 1 nodes remains
# After deleting nodes degree < 900, 1 nodes remains
# After deleting nodes degree < 901, 1 nodes remains
# After deleting nodes degree < 902, 1 nodes remains
# After deleting nodes degree < 903, 1 nodes remains
# After deleting nodes degree < 904, 1 nodes remains
# After deleting nodes degree < 905, 1 nodes remains
# After deleting nodes degree < 906, 1 nodes remains
# After deleting nodes degree < 907, 1 nodes remains
# After deleting nodes degree < 908, 1 nodes remains
# After deleting nodes degree < 909, 1 nodes remains
# After deleting nodes degree < 910, 1 nodes remains
# After deleting nodes degree < 911, 1 nodes remains
# After deleting nodes degree < 912, 1 nodes remains
# After deleting nodes degree < 913, 1 nodes remains
# After deleting nodes degree < 914, 1 nodes remains
# After deleting nodes degree < 915, 1 nodes remains
# After deleting nodes degree < 916, 1 nodes remains
# After deleting nodes degree < 917, 1 nodes remains
# After deleting nodes degree < 918, 1 nodes remains
# After deleting nodes degree < 919, 1 nodes remains
# After deleting nodes degree < 920, 1 nodes remains
# After deleting nodes degree < 921, 1 nodes remains
# After deleting nodes degree < 922, 1 nodes remains
# After deleting nodes degree < 923, 1 nodes remains
# After deleting nodes degree < 924, 1 nodes remains
# After deleting nodes degree < 925, 1 nodes remains
# After deleting nodes degree < 926, 1 nodes remains
# After deleting nodes degree < 927, 1 nodes remains
# After deleting nodes degree < 928, 1 nodes remains
# After deleting nodes degree < 929, 1 nodes remains
# After deleting nodes degree < 930, 1 nodes remains
# After deleting nodes degree < 931, 1 nodes remains
# After deleting nodes degree < 932, 1 nodes remains
# After deleting nodes degree < 933, 1 nodes remains
# After deleting nodes degree < 934, 1 nodes remains
# After deleting nodes degree < 935, 1 nodes remains
# After deleting nodes degree < 936, 1 nodes remains
# After deleting nodes degree < 937, 1 nodes remains
# After deleting nodes degree < 938, 1 nodes remains
# After deleting nodes degree < 939, 1 nodes remains
# ...
# After deleting nodes degree < 2239, 1 nodes remains
# After deleting nodes degree < 2240, 1 nodes remains
# After deleting nodes degree < 2241, 1 nodes remains
# After deleting nodes degree < 2242, 1 nodes remains
# After deleting nodes degree < 2243, 1 nodes remains
# After deleting nodes degree < 2244, 1 nodes remains
# After deleting nodes degree < 2245, 1 nodes remains
# After deleting nodes degree < 2246, 1 nodes remains
# After deleting nodes degree < 2247, 1 nodes remains
# After deleting nodes degree < 2248, 1 nodes remains
# After deleting nodes degree < 2249, 1 nodes remains
# After deleting nodes degree < 2250, 1 nodes remains
# After deleting nodes degree < 2251, 1 nodes remains
# After deleting nodes degree < 2252, 1 nodes remains
# After deleting nodes degree < 2253, 1 nodes remains
# After deleting nodes degree < 2254, 1 nodes remains
# After deleting nodes degree < 2255, 1 nodes remains
# After deleting nodes degree < 2256, 1 nodes remains
# After deleting nodes degree < 2257, 1 nodes remains
# After deleting nodes degree < 2258, 1 nodes remains
# After deleting nodes degree < 2259, 1 nodes remains
# After deleting nodes degree < 2260, 1 nodes remains
# After deleting nodes degree < 2261, 1 nodes remains
# After deleting nodes degree < 2262, 1 nodes remains
# After deleting nodes degree < 2263, 1 nodes remains
# After deleting nodes degree < 2264, 1 nodes remains
# After deleting nodes degree < 2265, 1 nodes remains
# After deleting nodes degree < 2266, 1 nodes remains
# After deleting nodes degree < 2267, 1 nodes remains
# After deleting nodes degree < 2268, 1 nodes remains
# After deleting nodes degree < 2269, 1 nodes remains
# After deleting nodes degree < 2270, 1 nodes remains
# After deleting nodes degree < 2271, 1 nodes remains
# After deleting nodes degree < 2272, 1 nodes remains
# After deleting nodes degree < 2273, 1 nodes remains
# After deleting nodes degree < 2274, 1 nodes remains
# After deleting nodes degree < 2275, 1 nodes remains
# After deleting nodes degree < 2276, 1 nodes remains
# After deleting nodes degree < 2277, 1 nodes remains
# After deleting nodes degree < 2278, 1 nodes remains
# After deleting nodes degree < 2279, 1 nodes remains
# After deleting nodes degree < 2280, 1 nodes remains
# After deleting nodes degree < 2281, 1 nodes remains
# After deleting nodes degree < 2282, 1 nodes remains
# After deleting nodes degree < 2283, 1 nodes remains
# After deleting nodes degree < 2284, 1 nodes remains
# After deleting nodes degree < 2285, 1 nodes remains
# After deleting nodes degree < 2286, 1 nodes remains
# After deleting nodes degree < 2287, 1 nodes remains
# After deleting nodes degree < 2288, 1 nodes remains
# After deleting nodes degree < 2289, 1 nodes remains
# After deleting nodes degree < 2290, 1 nodes remains
# After deleting nodes degree < 2291, 1 nodes remains
# After deleting nodes degree < 2292, 1 nodes remains
# After deleting nodes degree < 2293, 1 nodes remains
# After deleting nodes degree < 2294, 1 nodes remains
# After deleting nodes degree < 2295, 1 nodes remains
# After deleting nodes degree < 2296, 1 nodes remains
# After deleting nodes degree < 2297, 1 nodes remains
# After deleting nodes degree < 2298, 1 nodes remains
# After deleting nodes degree < 2299, 1 nodes remains
# After deleting nodes degree < 2300, 1 nodes remains
# After deleting nodes degree < 2301, 1 nodes remains
# After deleting nodes degree < 2302, 1 nodes remains
# After deleting nodes degree < 2303, 1 nodes remains
# After deleting nodes degree < 2304, 1 nodes remains
# After deleting nodes degree < 2305, 1 nodes remains
# After deleting nodes degree < 2306, 1 nodes remains
# After deleting nodes degree < 2307, 1 nodes remains
# After deleting nodes degree < 2308, 1 nodes remains
# After deleting nodes degree < 2309, 1 nodes remains
# After deleting nodes degree < 2310, 1 nodes remains
# After deleting nodes degree < 2311, 1 nodes remains
# After deleting nodes degree < 2312, 1 nodes remains
# After deleting nodes degree < 2313, 1 nodes remains
# After deleting nodes degree < 2314, 1 nodes remains
# After deleting nodes degree < 2315, 1 nodes remains
# After deleting nodes degree < 2316, 1 nodes remains
# After deleting nodes degree < 2317, 1 nodes remains
# After deleting nodes degree < 2318, 1 nodes remains
# After deleting nodes degree < 2319, 1 nodes remains
# After deleting nodes degree < 2320, 1 nodes remains
# After deleting nodes degree < 2321, 1 nodes remains
# After deleting nodes degree < 2322, 1 nodes remains
# After deleting nodes degree < 2323, 1 nodes remains
# After deleting nodes degree < 2324, 1 nodes remains
# After deleting nodes degree < 2325, 1 nodes remains
# After deleting nodes degree < 2326, 1 nodes remains
# After deleting nodes degree < 2327, 1 nodes remains
# After deleting nodes degree < 2328, 1 nodes remains
# After deleting nodes degree < 2329, 1 nodes remains
# After deleting nodes degree < 2330, 1 nodes remains
# After deleting nodes degree < 2331, 1 nodes remains
# After deleting nodes degree < 2332, 1 nodes remains
# After deleting nodes degree < 2333, 1 nodes remains
# After deleting nodes degree < 2334, 1 nodes remains
# After deleting nodes degree < 2335, 1 nodes remains
# After deleting nodes degree < 2336, 1 nodes remains
# After deleting nodes degree < 2337, 1 nodes remains
# After deleting nodes degree < 2338, 1 nodes remains
# After deleting nodes degree < 2339, 1 nodes remains
# After deleting nodes degree < 2340, 1 nodes remains
# After deleting nodes degree < 2341, 1 nodes remains
# After deleting nodes degree < 2342, 1 nodes remains
# After deleting nodes degree < 2343, 1 nodes remains
# After deleting nodes degree < 2344, 1 nodes remains
# After deleting nodes degree < 2345, 1 nodes remains
# After deleting nodes degree < 2346, 1 nodes remains
# After deleting nodes degree < 2347, 1 nodes remains
# After deleting nodes degree < 2348, 1 nodes remains
# After deleting nodes degree < 2349, 1 nodes remains
# After deleting nodes degree < 2350, 1 nodes remains
# After deleting nodes degree < 2351, 1 nodes remains
# After deleting nodes degree < 2352, 1 nodes remains
# After deleting nodes degree < 2353, 1 nodes remains
# After deleting nodes degree < 2354, 1 nodes remains
# After deleting nodes degree < 2355, 1 nodes remains
# After deleting nodes degree < 2356, 1 nodes remains
# After deleting nodes degree < 2357, 1 nodes remains
# After deleting nodes degree < 2358, 1 nodes remains
# After deleting nodes degree < 2359, 1 nodes remains
# After deleting nodes degree < 2360, 1 nodes remains
# After deleting nodes degree < 2361, 1 nodes remains
# After deleting nodes degree < 2362, 1 nodes remains
# After deleting nodes degree < 2363, 1 nodes remains
# After deleting nodes degree < 2364, 1 nodes remains
# After deleting nodes degree < 2365, 1 nodes remains
# After deleting nodes degree < 2366, 1 nodes remains
# After deleting nodes degree < 2367, 1 nodes remains
# After deleting nodes degree < 2368, 1 nodes remains
# After deleting nodes degree < 2369, 1 nodes remains
# After deleting nodes degree < 2370, 1 nodes remains
# After deleting nodes degree < 2371, 1 nodes remains
# After deleting nodes degree < 2372, 1 nodes remains
# After deleting nodes degree < 2373, 1 nodes remains
# After deleting nodes degree < 2374, 1 nodes remains
# After deleting nodes degree < 2375, 1 nodes remains
# After deleting nodes degree < 2376, 1 nodes remains
# After deleting nodes degree < 2377, 1 nodes remains
# After deleting nodes degree < 2378, 1 nodes remains
# After deleting nodes degree < 2379, 1 nodes remains
# After deleting nodes degree < 2380, 1 nodes remains
# After deleting nodes degree < 2381, 1 nodes remains
# After deleting nodes degree < 2382, 1 nodes remains
# After deleting nodes degree < 2383, 1 nodes remains
# After deleting nodes degree < 2384, 1 nodes remains
# After deleting nodes degree < 2385, 1 nodes remains
# After deleting nodes degree < 2386, 1 nodes remains
# After deleting nodes degree < 2387, 1 nodes remains
# After deleting nodes degree < 2388, 1 nodes remains
# After deleting nodes degree < 2389, 1 nodes remains
# After deleting nodes degree < 2390, 1 nodes remains
# After deleting nodes degree < 2391, 1 nodes remains
# After deleting nodes degree < 2392, 1 nodes remains
# After deleting nodes degree < 2393, 1 nodes remains
# After deleting nodes degree < 2394, 1 nodes remains
# After deleting nodes degree < 2395, 1 nodes remains
# After deleting nodes degree < 2396, 1 nodes remains
# After deleting nodes degree < 2397, 1 nodes remains
# After deleting nodes degree < 2398, 1 nodes remains
# After deleting nodes degree < 2399, 1 nodes remains
# After deleting nodes degree < 2400, 1 nodes remains
# After deleting nodes degree < 2401, 1 nodes remains
# After deleting nodes degree < 2402, 1 nodes remains
# After deleting nodes degree < 2403, 1 nodes remains
# After deleting nodes degree < 2404, 1 nodes remains
# After deleting nodes degree < 2405, 1 nodes remains
# After deleting nodes degree < 2406, 1 nodes remains
# After deleting nodes degree < 2407, 1 nodes remains
# After deleting nodes degree < 2408, 1 nodes remains
# After deleting nodes degree < 2409, 1 nodes remains
# After deleting nodes degree < 2410, 1 nodes remains
# After deleting nodes degree < 2411, 1 nodes remains
# After deleting nodes degree < 2412, 1 nodes remains
# After deleting nodes degree < 2413, 1 nodes remains
# After deleting nodes degree < 2414, 1 nodes remains
# After deleting nodes degree < 2415, 1 nodes remains
# After deleting nodes degree < 2416, 1 nodes remains
# After deleting nodes degree < 2417, 1 nodes remains
# After deleting nodes degree < 2418, 1 nodes remains
# After deleting nodes degree < 2419, 1 nodes remains
# After deleting nodes degree < 2420, 1 nodes remains
# After deleting nodes degree < 2421, 1 nodes remains
# After deleting nodes degree < 2422, 1 nodes remains
# After deleting nodes degree < 2423, 1 nodes remains
# After deleting nodes degree < 2424, 1 nodes remains
# After deleting nodes degree < 2425, 1 nodes remains
# After deleting nodes degree < 2426, 1 nodes remains
# After deleting nodes degree < 2427, 1 nodes remains
# After deleting nodes degree < 2428, 1 nodes remains
# After deleting nodes degree < 2429, 1 nodes remains
# After deleting nodes degree < 2430, 1 nodes remains
# After deleting nodes degree < 2431, 1 nodes remains
# After deleting nodes degree < 2432, 1 nodes remains
# After deleting nodes degree < 2433, 1 nodes remains
# After deleting nodes degree < 2434, 1 nodes remains
# After deleting nodes degree < 2435, 1 nodes remains
# After deleting nodes degree < 2436, 1 nodes remains
# After deleting nodes degree < 2437, 1 nodes remains
# After deleting nodes degree < 2438, 1 nodes remains
# After deleting nodes degree < 2439, 1 nodes remains
# After deleting nodes degree < 2440, 1 nodes remains
# After deleting nodes degree < 2441, 1 nodes remains
# After deleting nodes degree < 2442, 1 nodes remains
# After deleting nodes degree < 2443, 1 nodes remains
# After deleting nodes degree < 2444, 1 nodes remains
# After deleting nodes degree < 2445, 1 nodes remains
# After deleting nodes degree < 2446, 1 nodes remains
# After deleting nodes degree < 2447, 1 nodes remains
# After deleting nodes degree < 2448, 1 nodes remains
# After deleting nodes degree < 2449, 1 nodes remains
# After deleting nodes degree < 2450, 1 nodes remains
# After deleting nodes degree < 2451, 1 nodes remains
# After deleting nodes degree < 2452, 1 nodes remains
# After deleting nodes degree < 2453, 1 nodes remains
# After deleting nodes degree < 2454, 1 nodes remains
# After deleting nodes degree < 2455, 1 nodes remains
# After deleting nodes degree < 2456, 1 nodes remains
# After deleting nodes degree < 2457, 1 nodes remains
# After deleting nodes degree < 2458, 1 nodes remains
# After deleting nodes degree < 2459, 1 nodes remains
# After deleting nodes degree < 2460, 1 nodes remains
# After deleting nodes degree < 2461, 1 nodes remains
# After deleting nodes degree < 2462, 1 nodes remains
# After deleting nodes degree < 2463, 1 nodes remains
# After deleting nodes degree < 2464, 1 nodes remains
# After deleting nodes degree < 2465, 1 nodes remains
# After deleting nodes degree < 2466, 1 nodes remains
# After deleting nodes degree < 2467, 1 nodes remains
# After deleting nodes degree < 2468, 1 nodes remains
# After deleting nodes degree < 2469, 1 nodes remains
# After deleting nodes degree < 2470, 1 nodes remains
# After deleting nodes degree < 2471, 1 nodes remains
# After deleting nodes degree < 2472, 1 nodes remains
# After deleting nodes degree < 2473, 1 nodes remains
# After deleting nodes degree < 2474, 1 nodes remains
# After deleting nodes degree < 2475, 1 nodes remains
# After deleting nodes degree < 2476, 1 nodes remains
# After deleting nodes degree < 2477, 1 nodes remains
# After deleting nodes degree < 2478, 1 nodes remains
# After deleting nodes degree < 2479, 1 nodes remains
# After deleting nodes degree < 2480, 1 nodes remains
# After deleting nodes degree < 2481, 1 nodes remains
# After deleting nodes degree < 2482, 1 nodes remains
# After deleting nodes degree < 2483, 1 nodes remains
# After deleting nodes degree < 2484, 1 nodes remains
# After deleting nodes degree < 2485, 1 nodes remains
# After deleting nodes degree < 2486, 1 nodes remains
# After deleting nodes degree < 2487, 1 nodes remains
# After deleting nodes degree < 2488, 1 nodes remains
# After deleting nodes degree < 2489, 1 nodes remains
# After deleting nodes degree < 2490, 1 nodes remains
# After deleting nodes degree < 2491, 1 nodes remains
# After deleting nodes degree < 2492, 1 nodes remains
# After deleting nodes degree < 2493, 1 nodes remains
# After deleting nodes degree < 2494, 1 nodes remains
# After deleting nodes degree < 2495, 1 nodes remains
# After deleting nodes degree < 2496, 1 nodes remains
# After deleting nodes degree < 2497, 1 nodes remains
# After deleting nodes degree < 2498, 1 nodes remains
# After deleting nodes degree < 2499, 1 nodes remains
# After deleting nodes degree < 2500, 1 nodes remains
# After deleting nodes degree < 2501, 1 nodes remains
# After deleting nodes degree < 2502, 1 nodes remains
# After deleting nodes degree < 2503, 1 nodes remains
# After deleting nodes degree < 2504, 1 nodes remains
# After deleting nodes degree < 2505, 1 nodes remains
# After deleting nodes degree < 2506, 1 nodes remains
# After deleting nodes degree < 2507, 1 nodes remains
# After deleting nodes degree < 2508, 1 nodes remains
# After deleting nodes degree < 2509, 1 nodes remains
# After deleting nodes degree < 2510, 1 nodes remains
# After deleting nodes degree < 2511, 1 nodes remains
# After deleting nodes degree < 2512, 1 nodes remains
# After deleting nodes degree < 2513, 1 nodes remains
# After deleting nodes degree < 2514, 1 nodes remains
# After deleting nodes degree < 2515, 1 nodes remains
# After deleting nodes degree < 2516, 1 nodes remains
# After deleting nodes degree < 2517, 1 nodes remains
# After deleting nodes degree < 2518, 1 nodes remains
# After deleting nodes degree < 2519, 1 nodes remains
# After deleting nodes degree < 2520, 1 nodes remains
# After deleting nodes degree < 2521, 1 nodes remains
# After deleting nodes degree < 2522, 1 nodes remains
# After deleting nodes degree < 2523, 1 nodes remains
# After deleting nodes degree < 2524, 1 nodes remains
# After deleting nodes degree < 2525, 1 nodes remains
# After deleting nodes degree < 2526, 1 nodes remains
# After deleting nodes degree < 2527, 1 nodes remains
# After deleting nodes degree < 2528, 1 nodes remains
# After deleting nodes degree < 2529, 1 nodes remains
# After deleting nodes degree < 2530, 1 nodes remains
# After deleting nodes degree < 2531, 1 nodes remains
# After deleting nodes degree < 2532, 1 nodes remains
# After deleting nodes degree < 2533, 1 nodes remains
# After deleting nodes degree < 2534, 1 nodes remains
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-152-73033b54631e> in <module>()
#       6     k = 1
#       7     while (clean_pass <= core):
# ----> 8         core_old = count_author(bipartite_max_scc)
#       9         InDegV = snap.TIntPrV()
#      10         snap.GetNodeInDegV(bipartite_max_scc, InDegV)
#
# <ipython-input-90-41daf9f25c5a> in count_author(graph)
#       1 def count_author(graph):
# ----> 2     return len([node for node in graph.Nodes() if node.GetId()>=0])
#
# KeyboardInterrupt:

# %%
plt.figure(dpi=200, figsize=(4,3))
author = author_remaining[:76]
plt.plot(range(len(author)), author)
plt.yscale('log')
plt.xlabel('k-Core')
plt.ylabel('Author Count after\n Deleting Nodes Degree <= k')
plt.title('Author Count Vs. K-Core');

# %%
def kcore_reduction(graph, min_core):
    author_remaining = [len(authors)]
    core = 1
    while (core <= min_core):
        # For every core n, try to delete nodes with degree k=1,2,...n and check if the node count changes.
        # Make sure a clean pass (no node count change) for n times before increasing core to n+1
        clean_pass = 0 
        k = 1
        while (clean_pass <= core):
            core_old = count_author(graph)
            InDegV = snap.TIntPrV()
            snap.GetNodeInDegV(graph, InDegV)
            for item in InDegV:
                if item.GetVal2() == k:
                    graph.DelNode(item.GetVal1())
            # Update the graph, make sure it refers to the max SCC
            graph = snap.GetMxScc(graph)
            core_update = count_author(graph)
            if core_old != core_update:
                clean_pass = 0
            else:
                clean_pass += 1
            # Alter the degree count
            if k < core:
                k += 1
            elif k == core:
                k = 1
        print "After deleting nodes degree <= %d, %d nodes remains" % (core, core_update)
        author_remaining.append(core_update)
        core += 1
    return graph

# %%
bipartite_max_scc = snap.GetMxScc(bipartite)
small_graph = kcore_reduction(bipartite_max_scc, 25)
# Out:
# After deleting nodes degree < 1, 58950 nodes remains
# After deleting nodes degree < 2, 39980 nodes remains
# After deleting nodes degree < 3, 30605 nodes remains
# After deleting nodes degree < 4, 24345 nodes remains
# After deleting nodes degree < 5, 20158 nodes remains
# After deleting nodes degree < 6, 16995 nodes remains
# After deleting nodes degree < 7, 14401 nodes remains
# After deleting nodes degree < 8, 12626 nodes remains
# After deleting nodes degree < 9, 11192 nodes remains
# After deleting nodes degree < 10, 10167 nodes remains
# After deleting nodes degree < 11, 8837 nodes remains
# After deleting nodes degree < 12, 8024 nodes remains
# After deleting nodes degree < 13, 7442 nodes remains
# After deleting nodes degree < 14, 6746 nodes remains
# After deleting nodes degree < 15, 6105 nodes remains
# After deleting nodes degree < 16, 5755 nodes remains
# After deleting nodes degree < 17, 5317 nodes remains
# After deleting nodes degree < 18, 4996 nodes remains
# After deleting nodes degree < 19, 4674 nodes remains
# After deleting nodes degree < 20, 4249 nodes remains
# After deleting nodes degree < 21, 3806 nodes remains
# After deleting nodes degree < 22, 3584 nodes remains
# After deleting nodes degree < 23, 3459 nodes remains
# After deleting nodes degree < 24, 3311 nodes remains
# After deleting nodes degree < 25, 3053 nodes remains

# %% [markdown]
# ## Create Bi-partite graph with the reduced set of nodes

# %%
author_set = set()
project_set = set()
for node in small_graph.Nodes():
    node_id = node.GetId()
    if node_id < 0:
        project_set.add(node_id)
    else:
        author_set.add(node_id)

# %%
kcore_bi = snap.TUNGraph.New()
for author in author_set:
    kcore_bi.AddNode(author)
for project in project_set:
    kcore_bi.AddNode(project)
for _, row in project_authors.iterrows():
    if (-row['project_id'] in project_set) and (row['author_id'] in author_set):
        kcore_bi.AddEdge(-row['project_id'], row['author_id'])
kcore_bi.GetNodes(), kcore_bi.GetEdges()
# Out:
# (5215, 1081257)

# %%
authors = [node for node in kcore_bi.Nodes() if node.GetId()>=0]
len(authors), kcore_bi.GetNodes()-len(authors)
# Out:
# (3053, 2162)

# %%
author_deg = np.array([node.GetDeg() for node in kcore_bi.Nodes() if node.GetId()>=0])
X = np.unique(author_deg)
Y = [float((author_deg == i).sum())/len(author_deg) for i in X]
plt.loglog(X, Y)
plt.title('Reduced Max SCC Author Degree Distribution');

# %%
project_deg = np.array([node.GetDeg() for node in kcore_bi.Nodes() if node.GetId()<0])
X = np.unique(project_deg)
Y = [float((project_deg == i).sum())/len(project_deg) for i in X]
plt.loglog(X, Y)
plt.title('Reduced Max SCC Project Degree Distribution');

# %%
#The number of edge bridges in the max connected component
#An edge is a bridge if, when removed, increases the number of connected components.
EdgeV = snap.TIntPrV()
snap.GetEdgeBridges(kcore_bi, EdgeV)
len(EdgeV)
# Out:
# 0

# %%
# Approximate diameter of the max connected component
diam = snap.GetBfsFullDiam(kcore_bi, 100, False)
print diam
# Out:
# 11

# %%
print project_authors.shape
p1d = project_authors
p1d_kcore = p1d.loc[-p1d['project_id'].isin(project_set) & p1d['author_id'].isin(author_set)]
print p1d_kcore.shape
# Out:
# (1081257, 3)
# (228496, 3)

# %%
with open('./data/project_authors_2016_q1_k25core.pickle', 'wb') as picklefile:
    pickle.dump(p1d_kcore, picklefile, protocol=2)

# %% [markdown]
# ### Build bi-partite graph with the reduced kcore Q1 nodes for Q2 data

# %%
with open('./data/project_authors_2016_q2.pickle', 'rb') as picklefile:
    project_authors_q2 = pickle.load(picklefile)

# %%
project_set_q2 = set([-x for x in project_authors_q2.project_id.unique()]).intersection(project_set)
author_set_q2 = set(project_authors_q2.author_id.unique()).intersection(author_set)

# %%
kcore_bi_q2 = snap.TUNGraph.New()
for author in author_set_q2:
    kcore_bi_q2.AddNode(author)
for project in project_set_q2:
    kcore_bi_q2.AddNode(project)
for _, row in project_authors_q2.iterrows():
    if (-row['project_id'] in project_set_q2) and (row['author_id'] in author_set_q2):
        kcore_bi_q2.AddEdge(-row['project_id'], row['author_id'])
kcore_bi_q2.GetNodes(), kcore_bi_q2.GetEdges()
# Out:
# (4319, 84111)

# %%
print project_authors_q2.shape
p2d = project_authors_q2
p2d_kcore = p2d.loc[-p2d['project_id'].isin(project_set) & p2d['author_id'].isin(author_set)]
print p2d_kcore.shape
# Out:
# (827193, 3)
# (118607, 3)

# %%
with open('./data/project_authors_2016_q2_k25core.pickle', 'wb') as picklefile:
    pickle.dump(p2d_kcore, picklefile, protocol=2)
